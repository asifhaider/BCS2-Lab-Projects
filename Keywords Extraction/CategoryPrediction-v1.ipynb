# %% [markdown]
# # Predicting Computer Science Domain From Abstracts and Titles of Research Articles
# #### Using Machine Learning and Custom Keywords
#
# > **Important:** The original dataset doesnot contain any label. Conference titles have been used to label the dataset, and the modified version has been used here to understand the prediction accuracy. Relevant code cells might be omitted while testing on any unlabeled dataset.

# %% [markdown]
# # Setting Up Dependencies

# %%
# Mounting google drive location for correct directory path
# Might need google account authorization code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Necessary imports
import numpy as np
import pandas as pd
import tensorflow as tf
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer 
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import coo_matrix

# Necessary downloads
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Loading CSV Resource Files

# %%
# Loading the provided dataset, added column with labels from conference name  
dataset = pd.read_csv('/content/drive/MyDrive/Research/BCS2 Lab/Final/LabeledDataSetAllPapers.csv')

# %%
# Loading the custom keyword set
raw_keywords = pd.read_csv('/content/drive/MyDrive/Research/BCS2 Lab/Final/keywords.csv')

# %%
print("Dimensions of the input dataset: " + str(dataset.shape))
dataset.head()
# Out:
# Dimensions of the input dataset: (195830, 7)
#                   EID  ...                 Category
# 0  2-s2.0-36348977467  ...  Artificial intelligence
# 1  2-s2.0-36349036042  ...  Artificial intelligence
# 2  2-s2.0-36349024731  ...  Artificial intelligence
# 3  2-s2.0-36349006415  ...  Artificial intelligence
# 4  2-s2.0-36349000637  ...  Artificial intelligence
#
# [5 rows x 7 columns]

# %%
print("Dimensions of the custom keyword set: " + str(raw_keywords.shape))
raw_keywords.head()
# Out:
# Dimensions of the custom keyword set: (1339, 3)
#   Broader Category              Subcategory                 Keywords
# 0               AI  Artificial intelligence               Autonomous
# 1               AI  Artificial intelligence                Algorithm
# 2               AI  Artificial intelligence  Object Detection Models
# 3               AI  Artificial intelligence           Neural Network
# 4               AI  Artificial intelligence  Monte Carlo Tree Search

# %%
# initializing lemmatizer and stemmer 
lem = WordNetLemmatizer()
stem = PorterStemmer()

# %%
# extracting the hand lebeled keywords
category_keyword = {}
subcat = []
keywords = []
for i in range (raw_keywords.shape[0]):
  row = raw_keywords.iloc[i,:].tolist()
  if row[1] not in subcat:
    subcat.append(row[1])
    if(len(keywords)>0):
      category_keyword.update({subcat[-2]: list(set(keywords))})
      keywords = []
  value = row[2].split()  # splitting by space 

  for i in value:
    values = re.split('-|,|;',i)  # using regex for further cleaning 
    for j in values:
      j = j.lower()
      j = lem.lemmatize(j)
      # i = stem.stem(i)
      i = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ", i)
      # i = re.sub("(\\d|\\W)+", " ", i)
      keywords.append(j)

category_keyword.update({subcat[-1]: list(set(keywords))})  # extracting the unique ones
print('Custom hand labeled keywords by category: \n')
for i in category_keyword.keys():
  print(str(i) + ": " + str(len(category_keyword[i])))
  print(str(i) + ": " + str(category_keyword[i]))
  # print(str(category_keyword[i]))
# Out:
# Custom hand labeled keywords by category:
#
# Artificial intelligence: 69
# Artificial intelligence: ['object', 'programming', 'compression', 'translation', 'dynamic', 'information', 'query', 'scheduling', 'multiagent', 'neural', 'linear', 'tree', 'reasoning', 'augmentation', 'syntactic', 'semantic', 'filtering', 'environment', 'carlo', 'database', 'planning', 'resolution', 'mereological', 'stochastic', 'modeling', 'hybrid', 'learning', 'application', 'network', 'logic', 'temporal', 'robotic', 'relation', 'search', 'predictive', 'matching', 'prototyping', 'data', 'auction', 'algorithm', 'image', 'lexico', 'analysis', 'machine', 'deep', 'heuristic', 'monte', 'detection', 'rapid', 'representation', 'structure', 'system', 'permutation', 'pattern', 'pathfinding', 'space', 'design', 'autonomous', 'processing', 'exploration', 'simulation', 'and', 'model', 'summation', 'statistical', 'entity', 'calculus', 'combinatorial', 'web']
# Computer Vision: 68
# Computer Vision: ['object', 'kinematic', 'resonance', 'red', 'optical', 'distance', 'imaging', 'maximized', 'infra', 'naive', 'tree', 'component', 'leibler', 'recognition', 'flow', 'minimal', 'ground', 'vision', 'hyperspectral', 'estimation', 'helmholtz', 'based', 'layer', 'tensor', 'manifold', 'automatic', 'omnidirectional', 'identification', 'content', 'tolerant', 'camera', 'for', 'motion', 'stereopsis', 'multimodal', 'computed', 'fingerprint', 'clustering', 'principal', 'bayes', 'image', 'trace', 'analysis', 'magnetic', 'tomography', 'algorithm', 'real', 'topology', 'graphic', 'scene', 'hypothesis', 'transform', 'detection', 'retrieval', 'system', 'clutter', 'painting', 'symmetric', 'human', 'active', 'model', 'kullback', 'depth', 'egomotion', 'shape', 'augmented', 'imagery', 'gesture']
# Machine learning & data mining: 77
# Machine learning & data mining: ['reinforcement', 'most', 'multiplicative', 'indian', 'linear', 'tree', 'iterative', 'block', 'stochastic', 'parameter', 'determinantal', 'laplacian', 'analysis', 'point', 'category', 'model', 'maximum', 'margin', 'programming', 'crowdsourced', 'coordinate', 'based', 'spanning', 'graphical', 'learning', 'maximization', 'factor', 'large', 'structure', 'latent', 'parametric', 'information', 'generative', 'structured', 'mapping', 'buffet', 'support', 'non', 'like', 'method', 'max', 'nonparametric', 'process', 'algorithm', 'machine', 'collection', 'vector', 'feature', 'kernel', 'preserving', 'prediction', 'recurrent', 'dependency', 'decomposition', 'ascent', 'dynamic', 'ensemble', 'neural', 'bayesian', 'rule', 'incremental', 'continuous', 'network', 'discovery', 'explanation', 'statistic', 'performance', 'probable', 'embedding', 'data', 'energy', 'deep', 'scale', 'multi', 'combinatorial', 'hoeffding', 'gamma']
# Natural language processing: 76
# Natural language processing: ['grammar', 'dependency', 'role', 'translation', 'minimum', 'degree', 'grammatical', 'lattice', 'computational', 'tree', 'to', 'language', 'linguistics', 'predicate', 'linguistic', 'distributed', 'semantic', 'problem', 'on', 'markov', 'analogue', 'feedback', 'multilingual', 'syntactic', 'semantically', 'judgment', 'length', 'based', 'bilingual', 'automatic', 'context', 'risk', 'extended', 'combinatory', 'overlap', 'assisting', 'adjoining', 'parse', 'maximization', 'aligned', 'decision', 'chaining', 'source', 'optimization', 'argument', 'data', 'process', 'observable', 'bayes', 'configurable', 'segmentation', 'machine', 'framework', 'expectation', 'controlled', 'free', 'hyperspace', 'structure', 'constraint', 'partially', 'path', 'of', 'human', 'description', 'supervised', 'and', 'model', 'statistical', 'decoding', 'line', 'labeling', 'resource', 'tool', 'probabilistic', 'natural', 'categorial']
# The Web & information retrieval: 58
# The Web & information retrieval: ['relevance', 'information', 'query', 'targeting', 'rate', 'technique', 'divergence', 'language', 'browsing', 'principle', 'precision', 'probability', 'hierarchical', 'click', 'topic', 'jensen', 'based', 'document', 'learning', 'label', 'temporal', 'lingual', 'discounted', 'search', 'optimization', 'performance', 'weighting', 'gain', 'marginal', 'clustering', 'algorithm', 'engine', 'image', 'oriented', 'folksonomy', 'maximal', 'vector', 'cumulated', 'function', 'retrieval', 'interest', 'shannon', 'average', 'through', 'ranking', 'classification', 'multi', 'space', 'cross', 'processing', 'behavioral', 'model', 'quantum', 'loss', 'field', 'expected', 'web', 'author']
# Computer Architecture: 80
# Computer Architecture: ['parallel', 'organization', 'latency', 'dram', 'lookup', 'hardware', 'virtual', 'bound', 'packet', 'processor', 'overflow', 'computing', 'compiler', 'microarchitecture', 'checking', 'logging', 'model', 'threading', 'middleboxes', 'programming', 'compression', 'buffer', 'scheduling', 'up', 'microservices', 'flow', 'adverserial', 'streaming', 'accelerator', 'concurrency', 'flash', 'cloud', 'system', 'cache', 'simulation', 'operating', 'object', 'client', 'communication', 'query', 'linux', 'state', 'synchronization', 'debugging', 'drive', 'allocation', 'process', 'oriented', 'transformation', 'cluster', 'crash', 'quantum', 'resource', 'coherence', 'qubit', 'solid', 'integrity', 'memory', 'management', 'inter', 'distributed', 'testing', 'network', 'server', 'performance', 'optimization', 'embedding', 'data', 'architecture', 'adapter', 'serverless', 'shared', 'multi', 'design', 'datacenter', 'processing', 'memorization', 'consistency', 'persistancy', 'fourier']
# Compuer Networks: 45
# Compuer Networks: ['wifi', 'solid', 'internet', 'bit', 'memory', 'broadband', 'stream', 'security', 'firewall', 'address', 'state', 'node', 'disk', 'synchronization', 'hard', 'cellular', 'packet', 'dns', 'network', 'server', 'bandwidth', 'drive', 'wlan', 'data', 'gateway', 'automaton', 'switch', 'framework', 'mpls', 'router', 'topology', 'host', 'api', 'thing', 'cloud', 'cache', 'of', 'url', 'cyber', 'bitmap', 'wireless', 'isp', 'traffic', 'ip', 'capacity']
# Computer Security: 59
# Computer Security: ['hiding', 'blockchains', 'information', 'linux', 'verification', 'integrity', 'internet', 'technique', 'cryptography', 'language', 'flow', 'password', 'security', 'semantic', 'redesign', 'bug', 'victim', 'access', 'layer', 'mapping', 'module', 'learning', 'network', 'discretionary', 'iot', 'assembly', 'control', 'provider', 'protection', 'permission', 'lsm', 'algorithm', 'attack', 'robust', 'framework', 'machine', 'ih', 'protected', 'mitigation', 'cfi', 'encryption', 'interception', 'cpi', 'service', 'malicious', 'system', 'transmission', 'pointer', 'kernel', 'crowdsourcing', 'ecosystem', 'cross', 'traffic', 'sample', 'operating', 'fault', 'malware', 'tool', 'code']
# Databases: 49
# Databases: ['big', 'lcr', 'oracle', 'sql', 'information', 'query', 'extraction', 'xml', 'augmentation', 'graph', 'name', 'synthetic', 'first', 'vision', 'dbms', 'database', 'domain', 'based', 'mapping', 'queries.', 'learning', 'schema', 'strategy', 'traversal', 'dataset', 'search', 'approximate', 'data', 'computer', 'clustering', 'algorithm', 'analysis', 'machine', 'framework', 'approach', 'html', '(dfs)', 'datasets', 'cloud', 'service', 'mapreduce', 'integration', 'kernel', 'attribute', 'crowdsourcing', 'processing', 'hadoop', 'depth', 'entity']
# Design automation: 77
# Design automation: ['parallel', 'optical', 'linear', 'on', 'current', 'implementation', 'aes', 'stochastic', 'factorization', 'finder', 'processor', 'cad', 'sequential', 'computing', 'array', 'entropy', 'physically', 'test', 'cyber', 'pattern', 'ic', 'frame', 'biochip', 'field', 'programmable', 'signal', 'double', 'vlsi', 'synchronous', 'multiplication', 'based', 'gpu', 'unclonable', 'generation', 'assumption', 'image', 'service', 'system', 'simulation', 'communication', 'technology', 'quality', 'automatic', 'high', 'physical', 'lithography', 'chip', 'boolean', 'process', 'property', 'algorithm', 'circuit', 'vector', 'integrated', 'function', 'digital', 'cross', 'decompression', 'dynamic', 'implicit', 'inter', 'management', 'level', 'matrix', 'application', 'network', 'gate', 'optimization', 'intellectual', 'microfluidic', 'reliability', 'path', 'of', 'design', 'processing', 'synthesis', 'patterning']
# Embedded & real-time systems: 49
# Embedded & real-time systems: ['dependency', 'safety', 'networking', 'batteryless', 'parallel', 'signal', 'dynamic', 'command', 'scheduling', 'computational', 'flow', 'power', 'security', 'distributed', 'on', 'hardware', 'predictability', 'concurrence', 'based', 'software', 'single', 'timing', 'physical', 'critical', 'processor', 'control', 'chip', 'pc', 'aware', 'computer', 'data', 'tolerance', 'analysis', 'multitasking', 'sharing', 'forensics', 'peripheral', 'system', 'digital', 'cyber', 'task', 'wireless', 'processing', 'and', 'fault', 'contention', 'resource', 'embedded', 'device']
# High-performance computing: 79
# High-performance computing: ['', 'parallel', 'beyond', 'parallelism', 'computational', 'linear', 'porting', 'hardware', 'accuracy', 'molecular', 'exascale', 'analysis', 'point', 'sparsity', 'computing', 'compiler', 'test', 'weak', 'science', 'very', 'storage', 'benchmark', 'programmable', 'flow', 'power', 'container', 'based', 'modeling', 'software', 'gpu', 'learning', 'factorized', 'at', 'in', 'large', 'system', 'sustained', 'simulation', 'solution', 'algebra', 'communication', 'chemistry', '&', 'resilience', 'industrial', 'methodology', 'accelerated', 'reduction', 'efficient', 'material', 'modelling', 'specific', 'algorithm', 'knowledge', 'i/o', 'kernel', 'and', 'multiphysics', 'floating', 'quantum', 'throughput', 'tool', 'fluid', 'dynamic', 'memory', 'assimilation', 'management', 'to', 'resiliency', 'graph', 'application', 'network', 'time', 'optimization', 'data', 'deep', 'serverless', 'scale', 'quantized']
# Mobile Computing: 84
# Mobile Computing: ['localization', 'pulse', 'deployment', 'robustness', 'security', 'phone', 'light', 'stochastic', 'standard', 'factorization', 'wea', 'epc', 'attack', 'presidential', 'detection', 'spoofing', 'actuation', 'autonomous', 'ide', 'cot', 'runtime', 'deployed', 'nextepc', 'device', 'tablet', 'signal', 'monitoring', 'sdr', 'frequency', 'cmas', 'based', 'prototype', 'software', 'gps', 'gastronomy', 'error', 'iot', 'tracking', 'srslte', 'protection', 'detector', '3gpp', 'hotspot', 'deviation', 'plugin', 'skeleton', 'wireless', 'communication', 'smartphones', 'reactive', 'visible', 'aami', 'alert', 'fake', 'acoustic', 'knapsack', 'rf', 'microwave', 'limited', 'camera', 'computer', 'protocol', 'lte', 'mobility', 'digital', 'microphone', 'backscatter', 'cell', 'privacy', 'vision', 'sensor', 'uavs', 'drone', 'matrix', 'defined', 'control', 'data', 'shockwave', 'average', 'electrode', 'robot', 'sensing', 'radio', 'signature']
# Measurement & perf. analysis: 120
# Measurement & perf. analysis: ['big', 'latency', 'driver', 'computational', '3d', 'trade', '(rapl)', 'decoupling', 'abstract', 'bound', 'ng', 'serviceability', 'clustering', 'analysis', 'taito', 'computing', 'pacing', 'off', 'enterprise', 'auto', 'join', 'pea', 'theory', 'model', 'fork', 'che’s', 'xpoint', 'storage', 'atomicity', 'scheduling', 'availability', 'monitoring', 'stream', 'power', 'streaming', 'sdn', 'saturation', 'ha', 'modeling', 'constrained', 'efficiency', 'software', 'market', 'convergence', 'supercomputing', 'estimate', 'answer', 'metric', 'parfullcms', 'framework', 'datasets', 'cloud', 'service', 'system', 'cache', 'straggler', 'skeleton', 'stress', 'simulation', 'distribution', 'empirical', 'overloaded', 'fog', 'workload', 'approximation', 'cpu', 'poisson', 'lru', 'technique', 'problem', 'quality', 'k', 'center', 'equilibrium', 'ssd', 'state', 'support', 'non', 'drive', 'measurement', 'effect', 'chance', 'experimentation', 'qoe', 'study', 'i/o', 'and', 'throughput', 'evaluation', 'running', 'profiling', 'limit', 'voip', 'solid', 'scaling', 'response', 'memory', 'management', 'browsing', 'replication', 'nand', 'application', 'queue', 'invariant', 'optane', 'time', 'performance', 'optimization', 'qos', 'data', 'energy', 'nonvolatile', 'caching', 'cost', 'scenario', 'operation', 'reliability', 'average', 'task', 'probabilistic']
# Operating Systems: 151
# Operating Systems: ['parallel', 'z', 'parallelism', 'rt', 'speed', 'instance', 'library', 'linear', 'micro', 'security', 'rtt', 'hardware', 'virtual', 'rootkits', 'pci', 'file', 'out', 'scalability', '10', 'node', 'disk', 'consumption', 'overflow', 'bsd', 'log', 'p', 'hpc', 'sequential', 'protected', 'isolation', 'vmm', 'cleaner', 'periodicity', 'space', 'hypervisors', 'runtime', 'device', 'storage', 'programming', 'buffer', 'handling', 'channel', 'algorithmic', 'stream', '(tvmm)', 'container', 'abstraction', 'binary', 'software', 'concurrency', 'monitor', 'virtuozzo', 'execution', 'voltage', 'primitive', 'clustered', 'tolerance', 'exokernel', 'hosting', 'service', 'dataflow', 'system', 'growth', 'locking', 'user', 'life', 'transfer', 'cpu', 'legacy', 'communication', 'sprite', 'linux', 'structured', 'fifo', 'writing', 'trusted', 'center', 'core', "vmware's", 'microbenchmarks', 'layer', 'interprocess', 'functionality', 'xen', 'kvm', 'virtualization', 'high', 'chip', 'mechanism', 'dispatching', 'vmi', 'switch', 'segment', 'machine', 'commodity', 'lguest', 'api', 'function', 'virtio', 'i/o', 'kernel', 'cluster', 'crash', 'mmu', 'resource', 'code', 'μ', 'typing', 'dynamic', 'scaling', 'multiprocessor', 'memory', 'management', 'recovery', 'mode', 'terra', 'accellerators', 'distributed', 'controller', 'graph', 'address', 'o', 'context', 'network', 'administrator', 'server', 'bandwidth', 'vertex', 'time', 'performance', 'control', 'solaris', 'iseries', 'window', 'data', 'energy', 'ported', 'real', 'compatibility', 'execute', 'battery', 'reliability', 'unix', 'exception', 'task', 'scale', 'dvs', 'lf', 'vserver', 'cubic', 'fault']
# Programming languages: 91
# Programming languages: ['', 'hoare', 'linear', 'tree', 'noninterference', 'reasoning', 'analytic', 'temporal', 'equivalence', 'semantics', 'denotational', 'analysis', 'expansion', 'computation', 'expression', 'compiler', 'test', 'side', 'seminaïve', 'programming', 'program', 'datafun', 'verification', 'regular', 'probability', 'pre', 'oblivious', 'logic', 'primitive', 'rewriting', 'automaton', 'arithmetic', 'second', 'guarded', 'order', 'foundation', 'service', 'structure', 'recursion', 'system', 'cyclic', 'post', 'algebra', 'object', 'query', 'mathematics', 'reverse', 'proof', 'language', 'type', 'state', 'uninterpreted', 'separation', 'verified', 'effect', 'coinduction', 'with', 'taylor', 'i/o', 'polymorphism', 'undecidability', 'and', 'dependent', 'evaluation', 'equational', 'relative', 'scheme', 'cryptography', 'böhm', 'coq', 'database', 'kleene', 'correctness', 'incremental', 'monad', 'condition', 'optimization', 'functional', 'data', 'datalog', 'constraint', 'exception', 'static', 'processing', 'nondeterminism', 'relational', 'coalgebra', 'modal', 'calculus', 'haskell', 'lambda']
# Software engineering: 77
# Software engineering: ['localization', 'duplication', 'environment', 'bug', 'accuracy', 'mutation', '(mbfl)', 'gamification', 'development', 'stack', 'review', 'developer', 'analysis', 'overflow', 'mobile', 'maintenance', 'computing', 'theory', 'cognitive', 'programming', 'program', 'team', 'handling', 'inducing', 'configuration', 'based', 'software', 'learning', 'error', 'in', 'automated', 'framework', 'emf', 'repair', 'society', 'education', 'comprehension', 'bias', 'human', 'complexity', 'language', 'eclipse', 'clone', 'automatic', 'debugging', 'engineering', 'machine', 'course', 'centered', 'api', 'prediction', 'and', 'statistical', 'code', 'neural', 'sfl', 'recovery', 'interference', 'case', 'testing', 'privacy', 'maintaining', 'visualization', 'designing', 'license', 'application', 'network', 'evolution', 'autoencoder', 'performance', 'spectrum', 'commits', 'constraint', 'variational', 'static', 'fault', 'adaptive']
# Algorithms & complexity: 67
# Algorithms & complexity: ['constant', 'chain', 'complexity', 'parallel', 'approximation', 'minimum', 'bucket', 'massively', 'walk', 'dynamic', 'query', 'upper', 'sort', 'linear', 'α', 'gap', 'proof', 'k', 'random', 'graph', 'asymptotically', 'markov', 'sampling', 'black', 'weight', 'analog', 'knapsack', 'streaming', 'euclidean', 'transshipment', 'bound', 'tsp', 'oblivious', 'pseudocode', 'time', 'maximization', 'factor', 'edge', 'near', 'approximate', 'median', 'pagerank', 'relaxation', 'sublinear', 'algorithm', 'counting', 'sorting', 'encryption', 'shortest', 'directed', 'computation', 'subroutine', 'integrality', 'system', 'lower', 'parallelization', 'path', 'interactive', 'space', 'box', 'insertion', 'and', 'tight', 'runtime', 'merge', 'recursive', 'quicksort']
# Cryptography: 93
# Cryptography: ['parallel', 'cryptographic', 'rate', 'broken', 'random', 'security', 'euclid', 'cryptoanalytic', 'block', 'logarithmic', 'file', 'standard', 'processor', 'multiple', 'receiver', 'sorting', 'semantics', 'expansion', 'unauthorized', 'key', 'decoding', 'theory', 'cryptoanalyst', 'tradeoff', 'very', 'embedded', 'storage', 'reciprocal', 'vlsi', 'euclidean', 'software', 'trojan', 'plaintext', 'polynomial', 'protection', 'encrypted', 'large', 'automated', "patterson's", 'parameterization', 'voice', 'system', 'cryptoanalysis', 'read', 'complexity', 'public', 'secrecy', 'trusted', 'satellite', 'knapsack', 'microwave', 'mapping', 'synchronization', 'goppa', 'cipher', 'ciphertext', 'sender', 'generator', 'lsi', 'protocol', 'algorithm', 'machine', 'vector', 'inequality', 'malicious', 'digital', 'untrusted', 'code', 'secret', 'memory', 'cryptography', 'rsa', 'cryptosystem', 'privacy', 'access', 'attacker', 'crypto', 'matrix', 'de', 'teller', 'data', 'decryption', 'encryption', 'horse', 'authentication', 'integration', 'categorical', 'scale', 'processing', 'penetrator', 'signature', 'transit', 'input']
# Logic & Verification: 81
# Logic & Verification: ['semidefinite', 'concurrent', 'wl', 'reasoning', 'lean', 'leman', 'bound', 'cellular', 'genus', 'tuples', 'cohomology', 'weisfeiler', 'analysis', 'point', 'mechanized', 'smart', 'cyber', 'theory', 'higher', 'formal', 'parametricity', 'programming', 'verification', 'upper', 'flow', 'impredicativity', 'logic', 'sum', 'assistant', 'guarded', 'isomorphic', 'fpc', 'fo', 'recursion', 'system', 'fixed', 'tight', 'k+1', 'euler', 'information', 'finiteness', 'problem', 'proof', 'k', 'type', 'dimensional', 'group', 'method', 'physical', 'f', 'homotopy', 'process', 'algorithm', 'counting', 'with', 'lower', 'distinct', 'isomorphism', 'dependency', 'causal', 'dynamic', 'neural', 'grid', 'graph', 'hybrid', 'tuple', 'continuous', 'network', 'vertex', 'time', 'locale', 'quasipolynomial', 'integration', 'of', 'ellipsoid', 'square', 'clock', 'definable', 'iteration', 'calculus', 'combinatorial']
# Visualization: 54
# Visualization: ['object', 'cascaded', 'pixel', 'homology', 'locomotion', 'display', 'mesh', 'spatial', 'saliency', 'head', 'gaze', 'visualization', 'resolution', 'graphical', 'reconstruction', 'interaction', 'declarative', 'tracking', 'control', 'optimization', 'character', 'computed', 'specification', 'data', 'computer', 'capture', 'aided', 'tomography', 'image', 'analysis', 'graphic', 'analytics', 'color', 'topology', 'vector', 'mocap', 'detection', 'structure', 'visual', 'animation', 'system', 'interface', 'classification', 'human', 'design', 'layout', 'informatics', 'perception', 'user', 'cognitive', 'steganolysis', 'rendering', 'motion', 'mounted']
# Robotics: 79
# Robotics: ['localization', 'aerodynamics', 'slam', 'optical', 'cruise', 'environment', 'accuracy', 'manipulator', 'force', 'sonar', 'magnetic', 'analysis', 'pneumatic', 'radar', 'medical', 'traffic', 'model', 'aerial', 'unmanned', 'augmented', 'accelerometer', 'avoidance', 'tunneling', 'signal', 'imaging', 'locomotion', 'estimation', 'biomechanics', 'logic', 'actuator', 'representational', 'image', 'automation', 'system', 'torque', 'stress', 'road', 'human', 'kinematics', 'reality', 'rotor', 'state', 'routing', 'interaction', 'modelling', 'mechanism', 'trajectory', 'indoor', 'tensile', 'friction', 'baseline', 'pose', 'robotics', 'adaptation', 'dynamic', 'solid', 'propeller', 'collision', 'grippers', 'vehicle', 'vision', 'sensor', 'tactile', 'planning', 'stereo', 'drone', 'legged', 'correlation', 'control', 'path', 'robot', 'task', 'multi', 'processing', 'navigation', 'manufacturing', 'adaptive', 'inference', 'probabilistic']
# Economics and Computation: 52
# Economics and Computation: ['information', 'behavorial', 'economics', 'management', 'law', 'balancing', 'equilibrium', 'markov', 'privacy', 'social', 'stochastic', 'advertising', 'political', 'market', 'network', 'ridesharing', 'research', 'pricing', 'queue', 'interaction', 'game', 'maximization', 'labor', 'matching', 'optimization', 'commerce', 'auction', 'process', 'fairness', 'electronic', 'computing', 'operation', 'optimal', 'rationality', 'computation', 'system', 'of', 'crowdsourcing', 'convex', 'choice', 'cryptocurrency', 'revenue', 'science', 'incentive', 'theory', 'recommendation', 'applied', 'ethic', 'blockchain', 'combinatorial', 'device', 'load']
# Human Computer Interaction: 56
# Human Computer Interaction: ['programmable', 'communication', 'impairment', 'ethnography', 'information', 'technology', 'haptic', 'accessibility', 'ubiquitous', 'gestural', 'sequence', 'reality', 'testing', 'feedback', 'vision', 'disability', 'screen', 'social', 'production', 'material', 'interaction', 'community', 'experience', 'participatory', 'assistive', 'online', 'profession', 'pointing', 'policy', 'computer', 'prototyping', 'mixed', 'hci', 'auditory', 'analysis', 'mobile', 'immigrant', 'assistant', 'computing', 'centered', 'study', 'voice', 'culture', 'usability', 'interface', 'exchange', 'interactive', 'design', 'collaborative', 'user', 'input', 'field', 'touch', 'tool', 'device', 'human']
# Computational Biology and Bioinformatics: 166
# Computational Biology and Bioinformatics: ['taxonomic', 'duplication', 'biomedical', 'fluorescence', 'computational', 'phenotyping', 'tree', 'accessibility', 'adversarial', 'filtering', 'peroxisomes', 'domain', 'parsing', 'pssm', 'alignment', 'molecular', 'genomic', 'identification', 'mutation', 'single', 'differential', 'factorization', 'rna', 'omics', 'drug', 'mer', 'radiation', 'spectometry', 'seq', 'epigenomics', 'analysis', 'filter', 'binding', 'repeat', 'expression', 'progression', 'detection', 'filament', 'indel', 'microscopy', 'metabolomics', 'science', 'microbial', 'translation', 'imaging', 'health', 'mutant', 'biological', 'trait', 'split', 'dna', 'modeling', 'cytometry', 'training', 'integrative', 'xgboost', 'epidemiology', 'bioimage', 'actin', 'assembly', 'nmf', 'enumeration', 'cancer', 'ligand', 'bacteria', 'automated', 'structural', 'sgrna', 'optimal', 'genetic', 'biomarker', 'genetics', 'structure', 'system', 'mpsd', 'diagnosis', 'eeg', 'particle', 'population', 'behavioral', 'life', 'immunoinformatics', 'gene', 'public', 'information', 'regulation', 'protein', 'proteomics', 'antibody', 'k', 'sequence', 'biochemistry', 'ontology', 'method', 'max', 'diversity', 'tandem', 'depathing', 'set', 'kalman', 'nome', 'chromatin', 'haplotype', 'comparative', 'segmentation', 'dcj', 'knowledge', 'phylogenetics', 'hmm', 'bioinformatics', 'motif', 'disease', 'cross', 'prediction', 'infectious', 'knowledgebases', 'microbiomes', 'transcription', 'heterogenity', 'pharmacogenomics', 'epigenetics', 'methylation', 'organoid', 'evolutionary', 'pharmacogenetics', 'homology', 'decomposition', 'dynamic', 'identifiability', 'transmembrane', 'rearrangement', 'survival', 'morphology', 'polyprotein', 'tissue', 'cell', 'biology', 'graph', 'immunohistochemistry', 'replication', 'genomics', 'genome', 'application', 'peptide', 'network', 'variation', 'evolution', 'resistance', 'discovery', 'correlation', 'ray', 'functional', 'virus', 'clique', 'representation', 'clinical', 'x', 'variational', 'multi', 'tumor', 'signature', 'synthesis', 'metagenomics', 'inference', 'distance', 'informatics']
# Computer Graphics: 105
# Computer Graphics: ['localization', 'astronomy', 'computational', 'electroencephalography', '3d', 'novel', 'environment', 'virtual', 'light', 'sound', 'social', 'reconstruction', 'askap', 'globe', 'experience', 'haptics', 'gamification', 'intention', 'capture', 'engine', 'point', 'multiplane', 'space', 'medical', 'illustration', 'field', 'augmented', 'device', 'infrared', 'mesh', 'haptic', 'facial', 'drawing', 'based', 'learning', 'mush', 'tracking', 'generation', 'vr', 'mixed', 'image', 'graphic', 'cloud', 'view', 'system', 'growth', 'interface', 'fixed', 'animation', 'simulation', 'interpolation', 'user', 'star', 'paradigm', 'motion', 'audience', 'delta', 'stem', 'generative', '3dmm', 'reality', 'live', 'immersive', 'xr', 'photography', 'skinning', 'mapping', 'interaction', 'storytelling', 'unreal', 'modelling', 'open', 'matching', 'computer', 'catalog', 'sharing', 'tracing', 'visual', 'deformation', 'illumination', 'scaling', 'face', 'tangible', 'projection', 'visualization', 'notation', 'voxels', 'global', 'time', 'performance', 'ray', 'urban', 'character', 'data', 'chart', 'empathy', 'real', 'extrapolation', 'representation', 'attribute', 'design', 'radio', 'synthesis', 'surface', 'rendering']

# %%
print(category_keyword.keys())
print(category_keyword.values())
# Out:
# dict_keys(['Artificial intelligence', 'Computer Vision', 'Machine learning & data mining', 'Natural language processing', 'The Web & information retrieval', 'Computer Architecture', 'Compuer Networks', 'Computer Security', 'Databases', 'Design automation', 'Embedded & real-time systems', 'High-performance computing', 'Mobile Computing', 'Measurement & perf. analysis', 'Operating Systems', 'Programming languages', 'Software engineering', 'Algorithms & complexity', 'Cryptography', 'Logic & Verification', 'Visualization', 'Robotics', 'Economics and Computation', 'Human Computer Interaction', 'Computational Biology and Bioinformatics', 'Computer Graphics'])
# dict_values([['object', 'programming', 'compression', 'translation', 'dynamic', 'information', 'query', 'scheduling', 'multiagent', 'neural', 'linear', 'tree', 'reasoning', 'augmentation', 'syntactic', 'semantic', 'filtering', 'environment', 'carlo', 'database', 'planning', 'resolution', 'mereological', 'stochastic', 'modeling', 'hybrid', 'learning', 'application', 'network', 'logic', 'temporal', 'robotic', 'relation', 'search', 'predictive', 'matching', 'prototyping', 'data', 'auction', 'algorithm', 'image', 'lexico', 'analysis', 'machine', 'deep', 'heuristic', 'monte', 'detection', 'rapid', 'representation', 'structure', 'system', 'permutation', 'pattern', 'pathfinding', 'space', 'design', 'autonomous', 'processing', 'exploration', 'simulation', 'and', 'model', 'summation', 'statistical', 'entity', 'calculus', 'combinatorial', 'web'], ['object', 'kinematic', 'resonance', 'red', 'optical', 'distance', 'imaging', 'maximized', 'infra', 'naive', 'tree', 'component', 'leibler', 'recognition', 'flow', 'minimal', 'ground', 'vision', 'hyperspectral', 'estimation', 'helmholtz', 'based', 'layer', 'tensor', 'manifold', 'automatic', 'omnidirectional', 'identification', 'content', 'tolerant', 'camera', 'for', 'motion', 'stereopsis', 'multimodal', 'computed', 'fingerprint', 'clustering', 'principal', 'bayes', 'image', 'trace', 'analysis', 'magnetic', 'tomography', 'algorithm', 'real', 'topology', 'graphic', 'scene', 'hypothesis', 'transform', 'detection', 'retrieval', 'system', 'clutter', 'painting', 'symmetric', 'human', 'active', 'model', 'kullback', 'depth', 'egomotion', 'shape', 'augmented', 'imagery', 'gesture'], ['reinforcement', 'most', 'multiplicative', 'indian', 'linear', 'tree', 'iterative', 'block', 'stochastic', 'parameter', 'determinantal', 'laplacian', 'analysis', 'point', 'category', 'model', 'maximum', 'margin', 'programming', 'crowdsourced', 'coordinate', 'based', 'spanning', 'graphical', 'learning', 'maximization', 'factor', 'large', 'structure', 'latent', 'parametric', 'information', 'generative', 'structured', 'mapping', 'buffet', 'support', 'non', 'like', 'method', 'max', 'nonparametric', 'process', 'algorithm', 'machine', 'collection', 'vector', 'feature', 'kernel', 'preserving', 'prediction', 'recurrent', 'dependency', 'decomposition', 'ascent', 'dynamic', 'ensemble', 'neural', 'bayesian', 'rule', 'incremental', 'continuous', 'network', 'discovery', 'explanation', 'statistic', 'performance', 'probable', 'embedding', 'data', 'energy', 'deep', 'scale', 'multi', 'combinatorial', 'hoeffding', 'gamma'], ['grammar', 'dependency', 'role', 'translation', 'minimum', 'degree', 'grammatical', 'lattice', 'computational', 'tree', 'to', 'language', 'linguistics', 'predicate', 'linguistic', 'distributed', 'semantic', 'problem', 'on', 'markov', 'analogue', 'feedback', 'multilingual', 'syntactic', 'semantically', 'judgment', 'length', 'based', 'bilingual', 'automatic', 'context', 'risk', 'extended', 'combinatory', 'overlap', 'assisting', 'adjoining', 'parse', 'maximization', 'aligned', 'decision', 'chaining', 'source', 'optimization', 'argument', 'data', 'process', 'observable', 'bayes', 'configurable', 'segmentation', 'machine', 'framework', 'expectation', 'controlled', 'free', 'hyperspace', 'structure', 'constraint', 'partially', 'path', 'of', 'human', 'description', 'supervised', 'and', 'model', 'statistical', 'decoding', 'line', 'labeling', 'resource', 'tool', 'probabilistic', 'natural', 'categorial'], ['relevance', 'information', 'query', 'targeting', 'rate', 'technique', 'divergence', 'language', 'browsing', 'principle', 'precision', 'probability', 'hierarchical', 'click', 'topic', 'jensen', 'based', 'document', 'learning', 'label', 'temporal', 'lingual', 'discounted', 'search', 'optimization', 'performance', 'weighting', 'gain', 'marginal', 'clustering', 'algorithm', 'engine', 'image', 'oriented', 'folksonomy', 'maximal', 'vector', 'cumulated', 'function', 'retrieval', 'interest', 'shannon', 'average', 'through', 'ranking', ' ...

# %%
count = 0
for i in (category_keyword.values()):
  for j in i:
    # print(j)
    count = count + 1
print("Total keywords: " + str(count))
# Out:
# Total keywords: 2062

# %% [markdown]
# # Inspecting The Columns (Optional)
# This dataset contains some entries that do not contain both title and abstract. Those are inspected and further dropped down. Final input dataset might not be this faulty. The notebook cells under this optional section can be commented out in that case. Otherwise, this section needs to be re-inspected and re-written by the checker.

# %%
print("Glimpse of Titles: ")
all_titles = dataset['Title']
print(all_titles.head())
print("\nGlimpse of Abstracts: ")
all_abstracts = dataset['Abstract']
print(all_abstracts.head())
# Out:
# Glimpse of Titles:
# 0    Photometric and geometric restoration of docum...
# 1    ESP: A logic of only-knowing, noisy sensing an...
# 2       Impromptu teams of heterogeneous mobile robots
# 3    The Virtual Solar-terrestrial Observatory: A d...
# 4    Reasoning about attribute authenticity in a we...
# Name: Title, dtype: object
#
# Glimpse of Abstracts:
# 0    The popularity of current hand-held digital im...
# 1    When reasoning about actions and sensors in re...
# 2    As robots become more involved in assisting us...
# 3    The Virtual Solar-Terrestrial Observatory is a...
# 4    The reliable authentication of user attributes...
# Name: Abstract, dtype: object

# %%
all_abstracts = dataset['Abstract']
valid_abstracts = []
invalid_index = []
for abs in range(len(all_abstracts)):
    if all_abstracts[abs] is not np.NaN:
        valid_abstracts.append(all_abstracts[abs])
    else:
      invalid_index.append(abs)
# valid_abstracts = np.array(valid_abstracts)
print("Shape of given abstracts: " + str(all_abstracts.shape))
# print("Shape of valid abstracts: " + str(valid_abstracts.shape))
print("Number of invalid abstracts: " + str(len(invalid_index)))
print("Invalid index range: " + "From " + str(invalid_index[0]) + " To " + str(invalid_index[-1])
      + ", Total: " + str(invalid_index[-1] - invalid_index[0] + 1) + "\n")
# all_titles
# Out:
# Shape of given abstracts: (195830,)
# Number of invalid abstracts: 2988
# Invalid index range: From 192842 To 195829, Total: 2988

# %% [markdown]
# # Statistical Exploration

# %%
# Fetching word count in the abstracts
dataset = dataset.loc[0:192841] # these are the valid ones 
dataset['word_count'] = dataset['Abstract'].apply(lambda x: len(str(x).split(" ")))
print("Words Per Abstract:")
dataset[['Abstract', 'word_count']]
# Out:
# Words Per Abstract:
#                                                  Abstract  word_count
# 0       The popularity of current hand-held digital im...         182
# 1       When reasoning about actions and sensors in re...         118
# 2       As robots become more involved in assisting us...         134
# 3       The Virtual Solar-Terrestrial Observatory is a...         124
# 4       The reliable authentication of user attributes...         132
# ...                                                   ...         ...
# 192837  Digital Illness can be conceptualized as a sta...         148
# 192838  This paper elaborates on a process to streamli...         139
# 192839  Social networks play an important role in the ...         138
# 192840  The current COVID-19 experience seems to expos...         135
# 192841  With the wide adoption of service-oriented arc...         203
#
# [192842 rows x 2 columns]

# %%
print('Descriptive Statistics: \n')
dataset.word_count.describe()
# Out:
# Descriptive Statistics:
# count    192842.00000
# mean        153.06259
# std          56.48467
# min           3.00000
# 25%         117.00000
# 50%         150.00000
# 75%         185.00000
# max        1635.00000
# Name: word_count, dtype: float64

# %%
dataset = dataset.drop('word_count', axis = 1) # dropping the intermediate word_count column, after inspection done

# %%
# print('Most common entries: \n') 
# most_freq = pd.Series(''.
#                 join(dataset['Abstract']).split()).value_counts()
# most_freq[:1000]

# %%
# print('Least common entries: \n') 
# least_freq = pd.Series(''.
#                 join(dataset['Abstract']).split()).value_counts()
# least_freq[-100:]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Handling Stop Words

# %%
# stop words
stop_words = set(stopwords.words("english"))
print('Stop words from library: ' + str(len(stop_words)))
# Out:
# Stop words from library: 179

# %%
# custom stop words
custom_stop_size = 300
most_freq = pd.Series(''.
                join(dataset['Abstract']).split()).value_counts().index.tolist()[:custom_stop_size]
# most_freq
new_words = []
for i in most_freq:
    if i not in stop_words:
        new_words.append(i)
print('Custom stop words: ' + str(len(new_words)))
# Out:
# Custom stop words: 230

# %%
stop_words = stop_words.union(new_words)
print('Total stop words: ' + str(len(stop_words)))
# Out:
# Total stop words: 409

# %% [markdown]
# ### Handling Punctuations, Upper Cases, Special Characters

# %%
# using regex, splitting, lemmatizer and stemmer to clean data
corpus = []
for i in range(dataset['Abstract'].shape[0]):  
    # removing punctuations
    text = re.sub('[^a-zA-Z]', ' ', dataset['Abstract'][i])
    text2 = re.sub('[^a-zA-Z]', ' ', dataset['Title'][i])
    # lowercasing
    text = text.lower()
    text2 = text2.lower()
    # removing tags (<>)
    text = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ", text)
    text2 = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ", text2)
    # removing special characters and digits
    text = re.sub("(\\d|\\W)+", " ", text)
    text2 = re.sub("(\\d|\\W)+", " ", text2)
    # string to list of words
    text = text.split()
    text2 = text2.split()
    
    # stemming
    # text = [stem.stem(word) for word in text if not word in stop_words]
    # text = " ".join(text)
    
    # lemmatizing and stemming
    text = [lem.lemmatize(word) for word in text if not word in stop_words]
    text2 = [lem.lemmatize(word) for word in text2 if not word in stop_words]
    # text = [stem.stem(word) for word in text]
    # text2 = [stem.stem(word) for word in text2]
    # print(text)
    # print(text2)
    text = text + text2
    text = " ".join(text)
    corpus.append(text)
print('Total number of words in whole corpus: ' + str(len(corpus)))
# Out:
# Total number of words in whole corpus: 192842

# %% [markdown]
# # Tf-idf Algorithm
#
# > Searches over the whole corpus to find the Term Frequency and Inverse Document Frequency metric of the dataset to extract important features relevant to each entries
#
# > Parameters: maximum threshold to ignore common values (max_df) and maximum number of extracted features (max_features)

# %%
# running a count vectorizer method 
cv = CountVectorizer(max_df = 0.7, stop_words=stop_words,
                    max_features = 25000)
X = cv.fit_transform(corpus)
# list(cv.vocabulary_.keys())[:100]

tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(X)

# getting features name
feature_names = cv.get_feature_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['3d', 'art', 'association', 'copyright', 'however', 'world'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# # Predicting Probable Category (A Single Row)

# %%
# fetch document for which keywords need to be extracted
def predict_category(token):  
  doc = corpus[token]

  # generate tf-idf for the given document 
  vector = tfidf_transformer.transform(cv.transform([doc]))
  return vector

def sort_coo(coo_matrix):
  tuples = zip(coo_matrix.col, coo_matrix.data)
  return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn):
  sorted_items = sorted_items[:topn]
  score_vals = []
  feature_vals = []

  for index, score in sorted_items:
    score_vals.append(round(score, 5))
    feature_vals.append(feature_names[index])
  results = {}
  for i in range(len(feature_vals)):
    results[feature_vals[i]] = score_vals[i]
  return results

# %%
token = 5

tf_idf_vector = predict_category(token)

sorted_items = sort_coo(tf_idf_vector.tocoo())

probable_keywords = extract_topn_from_vector(feature_names, sorted_items, 500)

print("\nTitle + Abstract:\n")
print(dataset['Title'][token])
print(dataset['Abstract'][token])
print("\nProbable Keywords:\n")
for k in probable_keywords:
  print(k, probable_keywords[k])
# Out:
# Title + Abstract:
#
# Posterior probability profiles for the automated assessment of the recovery of stroke patients
# Assessing recovery from stroke has been so far a time consuming procedure in which highly trained clinicians are required. This paper proposes a mechatronic platform which measures low forces and torques exerted by subjects. Class posterior probabilities are used as a quantitative and statistically sound tool to assess motor recovery from these force and torque measurements. The performance of the patients is expressed in terms of the posterior probability to belong to the class of normal subjects. The mechatronic platform together with the class posterior probabilities enables to automate motor recovery assessment without the need for highly trained clinicians. It is shown that the class posterior probability profiles are highly correlated, r ‚âà 0.8, with the well-established Fugl-Meyer scale assessment in motor recovery. These results have been obtained through careful feature subset selection procedures in order to prune the large feature set being generated. The overall approach is general and can be applied to many other health monitoring systems where different categories (diseased vs. healthy) can be identified. Copyright ¬© 2007, Association for the Advancement of Artificial Intelligence (www.aaai.org). All rights reserved.
#
# Probable Keywords:
#
# posterior 0.39181
# recovery 0.35494
# probability 0.28231
# mechatronic 0.22089
# assessment 0.21915
# motor 0.21421
# clinician 0.20803
# class 0.19366
# stroke 0.1782
# highly 0.16086
# torque 0.14812
# patient 0.14724
# profile 0.14146
# meyer 0.13529
# diseased 0.12627
# subject 0.12155
# procedure 0.11719
# force 0.11486
# trained 0.11474
# platform 0.10682
# exerted 0.10643
# prune 0.0919
# healthy 0.09056
# belong 0.08924
# automate 0.08828
# careful 0.08424
# assessing 0.082
# statistically 0.08028
# correlated 0.07605
# expressed 0.07552
# consuming 0.07283
# health 0.07261
# sound 0.07124
# ass 0.07122
# established 0.07004
# normal 0.0697
# quantitative 0.06764
# identified 0.06711
# monitoring 0.06547
# category 0.06454
# subset 0.06416
# far 0.06308
# automated 0.06158
# together 0.05895
# overall 0.05842
# proposes 0.05774
# selection 0.05755
# aaai 0.05722
# org 0.05665
# www 0.0562
# advancement 0.05569
# required 0.05489
# measurement 0.05472
# generated 0.05387
# obtained 0.05355
# enables 0.05262
# measure 0.05224
# shown 0.05168
# intelligence 0.05104
# artificial 0.05008
# tool 0.04652
# reserved 0.04443
# scale 0.04397
# association 0.03863
# copyright 0.03517

# %%
output_map = {}
for i in category_keyword.keys():
  output_map.update({i:0})
# print(output_map)

keyword_list = list(category_keyword.values())
category_list = list(category_keyword.keys())

# print(keyword_list)
# print(category_list)

for k in probable_keywords.keys():
  for v in keyword_list:
    if k in v:
      subcat = category_list[keyword_list.index(v)]
      output_map[subcat] = int(output_map[subcat]) + 1
print(output_map)

occurence = list(output_map.values())
output = list(output_map.keys())
print(occurence)
print(output)
print(output[occurence.index(max(output_map.values()))])
# Out:
# {'Artificial intelligence': 0, 'Computer Vision': 0, 'Machine learning & data mining': 2, 'Natural language processing': 1, 'The Web & information retrieval': 1, 'Computer Architecture': 0, 'Compuer Networks': 0, 'Computer Security': 1, 'Databases': 0, 'Design automation': 0, 'Embedded & real-time systems': 0, 'High-performance computing': 2, 'Mobile Computing': 1, 'Measurement & perf. analysis': 2, 'Operating Systems': 2, 'Programming languages': 1, 'Software engineering': 2, 'Algorithms & complexity': 0, 'Cryptography': 2, 'Logic & Verification': 0, 'Visualization': 0, 'Robotics': 2, 'Economics and Computation': 0, 'Human Computer Interaction': 1, 'Computational Biology and Bioinformatics': 2, 'Computer Graphics': 1}
# [0, 0, 2, 1, 1, 0, 0, 1, 0, 0, 0, 2, 1, 2, 2, 1, 2, 0, 2, 0, 0, 2, 0, 1, 2, 1]
# ['Artificial intelligence', 'Computer Vision', 'Machine learning & data mining', 'Natural language processing', 'The Web & information retrieval', 'Computer Architecture', 'Compuer Networks', 'Computer Security', 'Databases', 'Design automation', 'Embedded & real-time systems', 'High-performance computing', 'Mobile Computing', 'Measurement & perf. analysis', 'Operating Systems', 'Programming languages', 'Software engineering', 'Algorithms & complexity', 'Cryptography', 'Logic & Verification', 'Visualization', 'Robotics', 'Economics and Computation', 'Human Computer Interaction', 'Computational Biology and Bioinformatics', 'Computer Graphics']
# Machine learning & data mining

# %% [markdown]
# # Predicting For Whole Dataset and Measuring Accuracy

# %%
count = 0
result = []
for token in range((dataset.shape[0])):    
    tf_idf_vector = predict_category(token)
    sorted_items = sort_coo(tf_idf_vector.tocoo())
    probable_keywords = extract_topn_from_vector(feature_names, sorted_items, 500)
    
    output_map = {}
    for i in category_keyword.keys():
      output_map.update({i:0})
    keyword_list = list(category_keyword.values())
    category_list = list(category_keyword.keys())
    for k in probable_keywords.keys():
      for v in keyword_list:
        if k in v:
          subcat = category_list[keyword_list.index(v)]
          output_map[subcat] = int(output_map[subcat]) + 1
    occurence = list(output_map.values())
    output = list(output_map.keys())
    # print(output[occurence.index(max(output_map.values()))])
    result.append(output[occurence.index(max(output_map.values()))])
    if result[token] == dataset['Category'][token]:
        count = count + 1

# %% [markdown]
# **Parameters and Hyperparameter List For Below Accuracy:**
# 1. Custom Stop Words: 300 (230 Effective)
# 2. Lemmatizing: On
# 3. Stemming: Off
# 4. CountVectorizer max_df: 0.7
# 5. CountVectorizer max_features: 25000 (Top 500 Chosen)
# 6. Total Custom Keywords After Processing: 2062

# %%
print("Accuracy: " + str(round(((count/dataset.shape[0])*100),3)) + "%")
# Out:
# Accuracy: 25.24%

# %% [markdown]
# # Writing The Output To New CSV File

# %%
filename = "/content/drive/MyDrive/Research/BCS2 Lab/Final/output.csv"
# adding newest column from list
dataset = dataset.drop('Category', axis = 1)
dataset['Prediction'] = result
dataset
# Out:
#                        EID  ...                       Prediction
# 0       2-s2.0-36348977467  ...                 Mobile Computing
# 1       2-s2.0-36349036042  ...            Programming languages
# 2       2-s2.0-36349024731  ...            Computer Architecture
# 3       2-s2.0-36349006415  ...       Human Computer Interaction
# 4       2-s2.0-36349000637  ...          Artificial intelligence
# ...                    ...  ...                              ...
# 192837  2-s2.0-85099545860  ...                Design automation
# 192838  2-s2.0-85099544945  ...                Computer Security
# 192839  2-s2.0-85099543353  ...      Natural language processing
# 192840  2-s2.0-85099536986  ...                 Mobile Computing
# 192841  2-s2.0-85099532359  ...  The Web & information retrieval
#
# [192842 rows x 7 columns]

# %%
dataset.to_csv(filename)
