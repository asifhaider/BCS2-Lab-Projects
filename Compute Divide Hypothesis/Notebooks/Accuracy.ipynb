# %% [markdown]
# # Data Load

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Research/BCS2 Lab/Papers With Code Test/Question Answering/Squad2.0/v1.csv', encoding='latin-1')
df
# Out:
#                 Model  EM Score  F1 Score  Year
# 0              IE-Net    90.939    93.214  2021
# 1               FPNet    90.871    93.183  2021
# 2            IE-NetV2    90.860    93.100  2021
# 3    SA-Net on Albert    90.724    93.011  2020
# 4           SA-Net-V2    90.679    92.948  2020
# ..                ...       ...       ...   ...
# 269               NaN    27.217    29.597  2019
# 270      CHECK SYSTEM     4.830     5.920  2018
# 271   5cls_squad1_fai     0.068     3.971  2019
# 272   Ensemble ALBERT    90.123       NaN  2020
# 273        gMLP-large    78.300       NaN  2021
#
# [274 rows x 4 columns]

# %% [markdown]
# # **Accuracy Check**

# %%
accuracies = list(df['EM Score'])
# accuracies
accuracy_dict = {'30-32':0,'32-34':0, '34-36':0, '36-38':0, '38-40':0,'40-42':0,'42-44':0, '44-46':0, '46-48':0, '48-50':0,'50-52':0,'52-54':0, '54-56':0, '56-58':0, '58-60':0, '60-62':0,'62-64':0, '64-66':0, '66-68':0, '68-70':0, '70-72':0,'72-74':0, '74-76':0, '76-78':0, '78-80':0, '80-82':0,'82-84':0, '84-86':0, '86-88':0, '88-90':0, '90-92':0,'92-94':0, '94-96':0, '96-98':0, '98-100':0}
# '10-12':0,'12-14':0, '14-16':0, '16-18':0, '18-20':0,'20-22':0,'22-24':0, '24-26':0, '26-28':0, '28-30':0, 

for i in accuracies:
  i = str(i)
  try:
    if i>='10%' and i<'12%':
        accuracy_dict['10-12'] = accuracy_dict['10-12'] + 1
      
    if i>='12%' and i<'14%':
        accuracy_dict['12-14'] = accuracy_dict['12-14'] + 1
      
    if i>='14%' and i<'16%':
        accuracy_dict['14-16'] = accuracy_dict['14-16'] + 1
      
    if i>='16%' and i<'18%':
        accuracy_dict['16-18'] = accuracy_dict['16-18'] + 1
      
    if i>='18%' and i<'20%':
        accuracy_dict['18-20'] = accuracy_dict['18-20'] + 1


    if i>='20%' and i<'22%':
        accuracy_dict['20-22'] = accuracy_dict['20-22'] + 1
      
    if i>='22%' and i<'24%':
        accuracy_dict['22-24'] = accuracy_dict['22-24'] + 1
      
    if i>='24%' and i<'26%':
        accuracy_dict['24-26'] = accuracy_dict['24-26'] + 1
      
    if i>='26%' and i<'28%':
        accuracy_dict['26-28'] = accuracy_dict['26-28'] + 1
      
    if i>='28%' and i<'30%':
        accuracy_dict['28-30'] = accuracy_dict['28-30'] + 1

    if i>='30%' and i<'32%':
        accuracy_dict['30-32'] = accuracy_dict['30-32'] + 1
      
    if i>='32%' and i<'34%':
        accuracy_dict['32-34'] = accuracy_dict['32-34'] + 1
      
    if i>='34%' and i<'36%':
        accuracy_dict['34-36'] = accuracy_dict['34-36'] + 1
      
    if i>='36%' and i<'38%':
        accuracy_dict['36-38'] = accuracy_dict['36-38'] + 1
      
    if i>='38%' and i<'40%':
        accuracy_dict['38-40'] = accuracy_dict['38-40'] + 1
    
    
    if i>='40%' and i<'42%':
        accuracy_dict['40-42'] = accuracy_dict['40-42'] + 1
      
    if i>='42%' and i<'44%':
        accuracy_dict['42-44'] = accuracy_dict['42-44'] + 1
      
    if i>='44%' and i<'46%':
        accuracy_dict['44-46'] = accuracy_dict['44-46'] + 1
      
    if i>='46%' and i<'48%':
        accuracy_dict['46-48'] = accuracy_dict['46-48'] + 1
      
    if i>='48%' and i<'50%':
        accuracy_dict['48-50'] = accuracy_dict['48-50'] + 1
    
    if i>='50%' and i<'52%':
        accuracy_dict['50-52'] = accuracy_dict['50-52'] + 1
      
    if i>='52%' and i<'54%':
        accuracy_dict['52-54'] = accuracy_dict['52-54'] + 1
      
    if i>='54%' and i<'56%':
        accuracy_dict['54-56'] = accuracy_dict['54-56'] + 1
      
    if i>='56%' and i<'58%':
        accuracy_dict['56-58'] = accuracy_dict['56-58'] + 1
      
    if i>='58%' and i<'60%':
        accuracy_dict['58-60'] = accuracy_dict['58-60'] + 1
      
    if i>='60%' and i<'62%':
        accuracy_dict['60-62'] = accuracy_dict['60-62'] + 1
      
    if i>='62%' and i<'64%':
        accuracy_dict['62-64'] = accuracy_dict['62-64'] + 1
      
    if i>='64%' and i<'66%':
        accuracy_dict['64-66'] = accuracy_dict['64-66'] + 1
      
    if i>='66%' and i<'68%':
        accuracy_dict['66-68'] = accuracy_dict['66-68'] + 1
      
    if i>='68%' and i<'70%':
        accuracy_dict['68-70'] = accuracy_dict['68-70'] + 1
      
    if i>='70%' and i<'72%':
        accuracy_dict['70-72'] = accuracy_dict['70-72'] + 1
      
    if i>='72%' and i<'74%':
        accuracy_dict['72-74'] = accuracy_dict['72-74'] + 1
      
    if i>='74%' and i<'76%':
        accuracy_dict['74-76'] = accuracy_dict['74-76'] + 1
      
    if i>='76%' and i<'78%':
        accuracy_dict['76-78'] = accuracy_dict['76-78'] + 1
      
    if i>='78%' and i<'80%':
        accuracy_dict['78-80'] = accuracy_dict['78-80'] + 1
      
    if i>='80%' and i<'82%':
        accuracy_dict['80-82'] = accuracy_dict['80-82'] + 1
      
    if i>='82%' and i<'84%':
        accuracy_dict['82-84'] = accuracy_dict['82-84'] + 1
      
    if i>='84%' and i<'86%':
        accuracy_dict['84-86'] = accuracy_dict['84-86'] + 1
      
    if i>='86%' and i<'88%':
        accuracy_dict['86-88'] = accuracy_dict['86-88'] + 1
      
    if i>='88%' and i<'90%':
        accuracy_dict['88-90'] = accuracy_dict['88-90'] + 1
      
    if i>='90%' and i<'92%':
        accuracy_dict['90-92'] = accuracy_dict['90-92'] + 1
      
    if i>='92%' and i<'94%':
        accuracy_dict['92-94'] = accuracy_dict['92-94'] + 1
      
    if i>='94%' and i<'96%':
        accuracy_dict['94-96'] = accuracy_dict['94-96'] + 1
      
    if i>='96%' and i<'98%':
        accuracy_dict['96-98'] = accuracy_dict['96-98'] + 1
      
    if i>='98%' and i<'99.99999999999':
        accuracy_dict['98-100'] = accuracy_dict['98-100'] + 1    
  except:
    continue
  
accuracy_dict
# Out:
# {'30-32': 0,
#  '32-34': 0,
#  '34-36': 0,
#  '36-38': 0,
#  '38-40': 1,
#  '40-42': 1,
#  '42-44': 0,
#  '44-46': 1,
#  '46-48': 0,
#  '48-50': 3,
#  '50-52': 0,
#  '52-54': 0,
#  '54-56': 0,
#  '56-58': 3,
#  '58-60': 3,
#  '60-62': 0,
#  '62-64': 4,
#  '64-66': 3,
#  '66-68': 2,
#  '68-70': 8,
#  '70-72': 9,
#  '72-74': 9,
#  '74-76': 12,
#  '76-78': 6,
#  '78-80': 19,
#  '80-82': 24,
#  '82-84': 25,
#  '84-86': 33,
#  '86-88': 35,
#  '88-90': 48,
#  '90-92': 23,
#  '92-94': 0,
#  '94-96': 0,
#  '96-98': 0,
#  '98-100': 0}

# %%
y = max(accuracy_dict.values())
x = list(accuracy_dict.keys())[list(accuracy_dict.values()).index(y)]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_val = list(accuracy_dict.keys())
y_val = list(accuracy_dict.values())
plt.xticks(rotation = 90)
plt.plot(x_val, y_val, marker = 'o')
plt.ylim(0, 60)
plt.axhline(y, ls = '-.', color = 'g')
plt.axvline(x, ls = '-.', color = 'g')
plt.title('Accuracy Analysis (' + 'SQuAD 2.0' + ')')
plt.xlabel('Accuracy (EM Score)')
plt.ylabel('Submissions')
plt.show()
